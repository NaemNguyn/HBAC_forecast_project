# %%
import pandas as pd

train  = pd.read_csv('../data/raw/train.csv', low_memory=False)
sample = pd.read_csv('../data/raw/sample_submission.csv')

train['Date'] = pd.to_datetime(train['Date'])

print(train.shape)
print(train.dtypes)
print(train.isnull().sum())

train.to_parquet('../data/raw/train_parsed.parquet', index=False)
sample.to_parquet('../data/raw/sample_submission.parquet', index=False)
# Out:
# (711980, 8)
# Date           datetime64[us]
# Stt                       str
# ItemCode                  str
# Quantity                int64
# UnitPrice                 str
# SalesAmount             int64
# Unit Cost                 str
# Cost Amount               str
# dtype: object
# Date           0
# Stt            0
# ItemCode       0
# Quantity       0
# UnitPrice      0
# SalesAmount    0
# Unit Cost      0
# Cost Amount    0
# dtype: int64
